# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Fake news article dataset

# %%
df = pd.read_csv("/content/train.csv")

# %%
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df = df.fillna('')
df.isnull().sum()

# %% [markdown]
# merging the author and title

# %%
df['content'] = df['title'] + df['author']
df['content']

# %%
df.info()

# %% [markdown]
# separating target

# %%
x = df['content'].values
y = df['label'].values

# %%
print(x)

# %%
print(y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Vectorizer = TfidfVectorizer()
Vectorizer.fit(x)
df1=Vectorizer.transform(x)

# %%
print(df1)
